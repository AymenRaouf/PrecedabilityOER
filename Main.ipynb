# %%
import os
import pandas as pd

main_publisher = 'MIT'

script_dir = os.path.dirname(os.path.realpath('__file__'))
path = os.path.join(script_dir, 'Data/' + main_publisher + '/')

df_chapters = pd.read_csv(path + 'chapters.csv', delimiter = '|')
df_episodes = pd.read_csv(path + 'episodes.csv', delimiter = '|')
df_series = pd.read_csv(path + 'series.csv', delimiter = '|')

# %%
df_chapters.head()
# Out:
#    Cid  Eid  Sid                                           Title
# 0    0    0    0  Lecture 1: Motivation, Intuition, and Examples  \
# 1    1    1    0                Lecture 2: General Theory Part 0
# 2    2    1    0                Lecture 2: General Theory Part 1
# 3    3    1    0                Lecture 2: General Theory Part 2
# 4    4    2    0            Lecture 3: Compact Sets in Rⁿ Part 0
#
#                                                 Text BeginTimestamp
# 0  [SQUEAKING] [RUSTLING] [CLICKING] PAIGE BRIGHT...        0:00:00  \
# 1  [SQUEAKING] [RUSTLING] [CLICKING] PAIGE BRIGHT...        0:00:00
# 2  I know that most of them-- in fact, infinitely...        0:21:44
# 3  You can replace R with just any metric space. ...        0:43:40
# 4  [SQUEAKING] [RUSTLING] [CLICKING] PAIGE BRIGHT...        0:00:00
#
#   EndTimestamp              Corpus
# 0      0:59:33  MIT OpenCourseWare
# 1      0:21:17  MIT OpenCourseWare
# 2      0:43:37  MIT OpenCourseWare
# 3      1:18:24  MIT OpenCourseWare
# 4      0:21:20  MIT OpenCourseWare

# %%
df_input = pd.read_csv('Extraction/khan.csv', delimiter = ',')
df_input.head()
# Out:
#                        Playlist Title       Channel   Category
# 0                  PL7A9646BC5110CF64  Khan Academy    Biology
# 1  PLSQl0a2vh4HDERCw_ddanXbsDpFWcpL-S  Khan Academy  Economics
# 2                  PLFD0EB975BA0CC1E0  Khan Academy      Maths
# 3  PLSQl0a2vh4HDCasLssY8bUV2qwDkZeOYL  Khan Academy      Maths
# 4                  PLD6DA74C1DBF770E7  Khan Academy      Maths
