# %%
from extraction import series_gen

series_gen('khan.csv', -1, -1, -1, save = True)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 from extraction import series_gen
# ----> 3 series_gen('khan.csv', -1, -1, -1, save = True)
#
# File ~/Documents/Code/PrerequisiteLearning/Extraction/extraction.py:83, in series_gen(csv_file, sid, eid, cid, save)
#      80 chapters = []
#      82 api_key = os.getenv('GOOGLE_API_KEY')
# ---> 83 youtube = build('youtube', 'v3', developerKey=api_key)
#      85 with open(csv_file, 'r') as f:
#      86     reader = csv.reader(f)
#
# File ~/Documents/Code/PrerequisiteLearning/clara-datasets/lib64/python3.10/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# ...
